# %% [markdown]
# 1. The Problem: A System That’s Not Predictable
# Imagine you have a "mystery box." Each time you look at it (or sample from it), it gives a number.
#
# The weird part: you don’t always get the same number. Sometimes it’s 3, sometimes 7, sometimes -1.
#
# If a system always gives the same result for the same input, it’s deterministic.
#
# But this box is not deterministic → it gives different numbers each time, even with no inputs.
#
# 👉 This is where probability comes in, because probability helps us describe and understand randomness.
#
# 2. Modeling Randomness with Probability Distributions
# Instead of trying to predict exactly what number will come out, we model the likelihood of possible outcomes.
#
# We use a Probability Distribution to describe:
#
# Which values might appear
#
# How likely each value is
#
# There are two kinds of distributions:
#
# Discrete Distributions – outcomes are separate, countable items.
#
# Example: coin toss (heads or tails).
#
# You can directly say P(heads) = 0.4, P(tails) = 0.6.
#
# Each distinct outcome has a probability.
#
# Continuous Distributions – outcomes can be any number within a range.
#
# Example: people’s heights. A person isn’t exactly 160.000000 cm; they might be 160.3 cm, 161.8 cm, etc.
#
# There are infinite possible values.
#
# So, instead of asking “What’s the probability someone is exactly 160 cm tall?” (which would be essentially zero), we ask “What’s the probability someone’s height is between 160 and 165 cm?”.
#
# 3. Probability Density Function (PDF)
# A PDF (probability density function) is the curve or function that describes the distribution of a random variable.
#
# For discrete cases, the probability is written directly.
#
# For continuous cases, we calculate probabilities by finding the area under the curve between two points.
#
# This uses calculus (integrals):
#
# Area under the curve = probability that the outcome falls within that range.
#
# 👉 Example: The probability that a person's height is between 160–165 cm = the integral of the PDF between 160 and 165.
#
# 4. Notation
# Probability is usually written with a big P. Example: P(heads) = 0.5.
#
# Probability density function itself is written with a small p. Example: p(y) means the density at value y.
#
# Random variables are typically written with capital letters (Y).
#
# Actual observed values (samples) are written with lowercase letters (y).
#
# Example:
#
# Y = the random variable describing "height."
#
# y = an observed sampled value, e.g. person’s height = 162.3 cm.
#
# 5. Random Variable
# A random variable is just a variable whose value is not fixed but changes when sampled.
#
# It’s not random in the "illogical" sense — it’s governed by a probability distribution.
#
# Example:
#
# Roll a die → random variable X = the outcome (1–6).
#
# Toss a coin → random variable C = (heads or tails).
#
# We usually write:
#
# Y ~ p(y) → means random variable Y is distributed according to distribution p(y).
#
# A dataset of size n = a collection of n samples of the random variable. Example: y1, y2, …, yn.
#
# 6. Connecting It All Together
# Let’s tie this with the "mystery box" example:
#
# Every time we sample the box, we get unpredictable numbers.
#
# To model this, we assume the outputs come from some distribution.
#
# By collecting many samples, we try to figure out what that distribution looks like (normal, uniform, etc.).
#
# Once we know the distribution, we can:
#
# Estimate probabilities (e.g., "How likely is the box to give a number between 10 and 15?")
#
# Understand whether outcomes are discrete (like dice rolls) or continuous (like human height).
#
# ✅ Beginner Takeaway
#
# Probability distributions are ways to describe randomness.
#
# Discrete = separate values (coin toss, dice).
#
# Continuous = any value within a range (heights, weights).
#
# Probabilities for continuous outcomes are computed over intervals, not exact single points.
#
# Random variables are the "mathematical names" for these unpredictable quantities.
