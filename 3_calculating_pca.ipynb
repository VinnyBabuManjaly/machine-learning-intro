# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Example: Load a dataset (California housing prices, ignoring target)
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import fetch_california_housing

X, _ = fetch_california_housing(return_X_y=True)
X = pd.DataFrame(X)
X
# Out:
#             0     1         2         3       4         5      6       7
# 0      8.3252  41.0  6.984127  1.023810   322.0  2.555556  37.88 -122.23
# 1      8.3014  21.0  6.238137  0.971880  2401.0  2.109842  37.86 -122.22
# 2      7.2574  52.0  8.288136  1.073446   496.0  2.802260  37.85 -122.24
# 3      5.6431  52.0  5.817352  1.073059   558.0  2.547945  37.85 -122.25
# 4      3.8462  52.0  6.281853  1.081081   565.0  2.181467  37.85 -122.25
# ...       ...   ...       ...       ...     ...       ...    ...     ...
# 20635  1.5603  25.0  5.045455  1.133333   845.0  2.560606  39.48 -121.09
# 20636  2.5568  18.0  6.114035  1.315789   356.0  3.122807  39.49 -121.21
# 20637  1.7000  17.0  5.205543  1.120092  1007.0  2.325635  39.43 -121.22
# 20638  1.8672  18.0  5.329513  1.171920   741.0  2.123209  39.43 -121.32
# 20639  2.3886  16.0  5.254717  1.162264  1387.0  2.616981  39.37 -121.24
#
# [20640 rows x 8 columns]

# %%
X.describe()
# Out:
#                   0             1             2             3             4  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.870671     28.639486      5.429000      1.096675   1425.476744
# std        1.899822     12.585558      2.474173      0.473911   1132.462122
# min        0.499900      1.000000      0.846154      0.333333      3.000000
# 25%        2.563400     18.000000      4.440716      1.006079    787.000000
# 50%        3.534800     29.000000      5.229129      1.048780   1166.000000
# 75%        4.743250     37.000000      6.052381      1.099526   1725.000000
# max       15.000100     52.000000    141.909091     34.066667  35682.000000
#
#                   5             6             7
# count  20640.000000  20640.000000  20640.000000
# mean       3.070655     35.631861   -119.569704
# std       10.386050      2.135952      2.003532
# min        0.692308     32.540000   -124.350000
# 25%        2.429741     33.930000   -121.800000
# 50%        2.818116     34.260000   -118.490000
# 75%        3.282261     37.710000   -118.010000
# max     1243.333333     41.950000   -114.310000

# %% [markdown]
# Standard variations vary quite a bit.
#
# Hence, shifting the data cloud to origin and normalize to make standard deviations to one.

# %%
mu = X.mean()
sigma = X.std()
X_norm = (X - mu) / sigma
X_norm.describe()
# Out:
#                   0             1             2             3             4  \
# count  2.064000e+04  2.064000e+04  2.064000e+04  2.064000e+04  2.064000e+04
# mean   4.406467e-17  1.101617e-17  6.885104e-17 -1.018995e-16 -1.514723e-17
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -1.774256e+00 -2.196127e+00 -1.852274e+00 -1.610729e+00 -1.256092e+00
# 25%   -6.881019e-01 -8.453727e-01 -3.994399e-01 -1.911670e-01 -5.637952e-01
# 50%   -1.767908e-01  2.864502e-02 -8.078293e-02 -1.010626e-01 -2.291262e-01
# 75%    4.592952e-01  6.642943e-01  2.519554e-01  6.015724e-03  2.644885e-01
# max    5.858144e+00  1.856137e+00  5.516190e+01  6.957003e+01  3.024960e+01
#
#                   5             6             7
# count  2.064000e+04  2.064000e+04  2.064000e+04
# mean   2.754042e-18 -1.035520e-15 -8.526513e-15
# std    1.000000e+00  1.000000e+00  1.000000e+00
# min   -2.289944e-01 -1.447533e+00 -2.385935e+00
# 25%   -6.170912e-02 -7.967694e-01 -1.113182e+00
# 50%   -2.431526e-02 -6.422715e-01  5.389006e-01
# 75%    2.037404e-02  9.729330e-01  7.784775e-01
# max    1.194162e+02  2.957996e+00  2.625216e+00

# %% [markdown]
# $$X_{norm} = U \Sigma V^T$$

# %%
from scipy.linalg import svd

U, s, Vt = svd(X_norm, full_matrices=False)

# Scipy svd returns slightly different values than the notation, hence slightly tweaking the values
Sigma = np.diag(s)
V = Vt.T

# %%
# Checking decomposition
U @ Sigma @ V.T
# Out:
# array([[ 2.34470896,  0.98211887,  0.62854423, ..., -0.04959533,
#          1.05252278, -1.32780305],
#        [ 2.33218146, -0.60700421,  0.32703343, ..., -0.09250999,
#          1.04315928, -1.32281187],
#        [ 1.78265622,  1.85613656,  1.15559247, ..., -0.0258419 ,
#          1.03847753, -1.33279424],
#        ...,
#        [-1.14256563, -0.92482882, -0.09031584, ..., -0.07173277,
#          1.77819439, -0.82369324],
#        [-1.05455737, -0.84537267, -0.04021014, ..., -0.09122294,
#          1.77819439, -0.87360511],
#        [-0.78011057, -1.00428498, -0.07044081, ..., -0.0436811 ,
#          1.75010387, -0.83367562]])

# %%
X_norm
# Out:
#               0         1         2         3         4         5         6  \
# 0      2.344709  0.982119  0.628544 -0.153754 -0.974405 -0.049595  1.052523
# 1      2.332181 -0.607004  0.327033 -0.263329  0.861418 -0.092510  1.043159
# 2      1.782656  1.856137  1.155592 -0.049015 -0.820757 -0.025842  1.038478
# 3      0.932945  1.856137  0.156962 -0.049832 -0.766010 -0.050328  1.038478
# 4     -0.012881  1.856137  0.344702 -0.032905 -0.759828 -0.085614  1.038478
# ...         ...       ...       ...       ...       ...       ...       ...
# 20635 -1.216099 -0.289180 -0.155020  0.077352 -0.512579 -0.049109  1.801603
# 20636 -0.691576 -0.845373  0.276874  0.462353 -0.944382  0.005021  1.806285
# 20637 -1.142566 -0.924829 -0.090316  0.049413 -0.369528 -0.071733  1.778194
# 20638 -1.054557 -0.845373 -0.040210  0.158774 -0.604415 -0.091223  1.778194
# 20639 -0.780111 -1.004285 -0.070441  0.138399 -0.033976 -0.043681  1.750104
#
#               7
# 0     -1.327803
# 1     -1.322812
# 2     -1.332794
# 3     -1.337785
# 4     -1.337785
# ...         ...
# 20635 -0.758808
# 20636 -0.818702
# 20637 -0.823693
# 20638 -0.873605
# 20639 -0.833676
#
# [20640 rows x 8 columns]

# %%
np.allclose(X_norm, U @ Sigma @ V.T)
# Out:
# True

# %% [markdown]
# Recovering the original dataset from decomposition
#   $$
#   X = {\mu} + {\sigma X_{norm}}
#   $$

# %%
mu + sigma * pd.DataFrame(U @ Sigma @ V.T)
# Out:
#             0     1         2         3       4         5      6       7
# 0      8.3252  41.0  6.984127  1.023810   322.0  2.555556  37.88 -122.23
# 1      8.3014  21.0  6.238137  0.971880  2401.0  2.109842  37.86 -122.22
# 2      7.2574  52.0  8.288136  1.073446   496.0  2.802260  37.85 -122.24
# 3      5.6431  52.0  5.817352  1.073059   558.0  2.547945  37.85 -122.25
# 4      3.8462  52.0  6.281853  1.081081   565.0  2.181467  37.85 -122.25
# ...       ...   ...       ...       ...     ...       ...    ...     ...
# 20635  1.5603  25.0  5.045455  1.133333   845.0  2.560606  39.48 -121.09
# 20636  2.5568  18.0  6.114035  1.315789   356.0  3.122807  39.49 -121.21
# 20637  1.7000  17.0  5.205543  1.120092  1007.0  2.325635  39.43 -121.22
# 20638  1.8672  18.0  5.329513  1.171920   741.0  2.123209  39.43 -121.32
# 20639  2.3886  16.0  5.254717  1.162264  1387.0  2.616981  39.37 -121.24
#
# [20640 rows x 8 columns]

# %%
np.allclose(X, mu + sigma * pd.DataFrame(U @ Sigma @ V.T))
# Out:
# True
